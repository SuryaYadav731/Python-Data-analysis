# %% [markdown]
# ### **IMPORT LIBRARY**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **IMPORT DATASET**

# %%
df = pd.read_csv(r'E:\project may\python\olm\athlete_events.csv')

# %% [markdown]
# ### **TOP 5**

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ### **LAST 5**

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %% [markdown]
# ### **SHAPE**

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.size
# Out:
# 4066740

# %% [markdown]
# ### **COLUMNS**

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# ### **RANDOM 4 Row**

# %%
df.sample(4)
# Out:
#             ID                                      Name Sex   Age  Height  \
# 165818   83293                      Wameedh Munir Yacoub   M   NaN     NaN
# 231945  116362        Francis Cornelius "Frank" Sullivan   M  34.0   180.0
# 4213      2414  Chimene Mary "Chemmy" Alcott (-Crawford)   F  27.0   169.0
# 43135    22243                  Veronica Cogeanu-Cochela   F  26.0   175.0
#
#         Weight           Team  NOC        Games  Year  Season         City  \
# 165818     NaN           Iraq  IRQ  1984 Summer  1984  Summer  Los Angeles
# 231945    81.0         Canada  CAN  1952 Winter  1952  Winter         Oslo
# 4213      69.0  Great Britain  GBR  2010 Winter  2010  Winter    Vancouver
# 43135     78.0        Romania  ROU  1992 Summer  1992  Summer    Barcelona
#
#                 Sport                          Event   Medal
# 165818       Football        Football Men's Football     NaN
# 231945     Ice Hockey    Ice Hockey Men's Ice Hockey    Gold
# ...

# %% [markdown]
# ### **INFORMATION**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# ### **DESCRIBE**

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ### **NULL**

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Height']=df['Height'].fillna(df['Height'].mean())
df['Weight']=df['Weight'].fillna(df['Weight'].mean())

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# ### **DUPLICATED**

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df= df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (269731, 15)

# %% [markdown]
# ### **CORRELATION**

# %%
numerical_data = df.select_dtypes(include=['number'])

# %%
numerical_data.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.002825 -0.009791 -0.008059  0.011381
# Age    -0.002825  1.000000  0.111115  0.168071 -0.088250
# Height -0.009791  0.111115  1.000000  0.786635  0.030126
# Weight -0.008059  0.168071  0.786635  1.000000  0.011598
# Year    0.011381 -0.088250  0.030126  0.011598  1.000000

# %% [markdown]
# ### **HEATMAP**

# %%
sns.heatmap(numerical_data.corr(), annot= True)
plt.show()

# %% [markdown]
# #### **UNIVERIATE**

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
Sex_distribution = df['Sex'].value_counts()

# %%
Sex_distribution.index
# Out:
# Index(['M', 'F'], dtype='object', name='Sex')

# %%
Sex_distribution.values
# Out:
# array([195353,  74378], dtype=int64)

# %%
sns.barplot(x=Sex_distribution.index, y =Sex_distribution.values)
plt.title("Gender Distribution in the olympic")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### ***DISPLAY THE TOP 10 MOST POPULAR SPORTS BASED ON ATHELETE PARTICIPATION***

# %%
top_10= df['Sport'].value_counts().head(10)
top_10
# Out:
# Sport
# Athletics               38624
# Gymnastics              26707
# Swimming                23195
# Shooting                11448
# Cycling                 10827
# Fencing                 10735
# Rowing                  10595
# Cross Country Skiing     9133
# Alpine Skiing            8829
# Wrestling                7154
# Name: count, dtype: int64

# %% [markdown]
# ### **BARPLOT**

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=top_10.index, y=top_10.values)
plt.title("Top 10 Sport")
plt.xlabel("Sport")
plt.ylabel("Number of Athelete")
plt.show()

# %% [markdown]
# ### **PIE CHART**

# %%
plt.figure(figsize=(14,14))

df['Sport'].value_counts().head(10).plot(kind='pie', autopct ='%1.2f%%')

plt.show()

# %% [markdown]
# ### **MOST POPULAR SPORT BASED ON ATHELETE PARTICIPATION**

# %%
df['Sport'].value_counts().idxmax()
# Out:
# 'Athletics'

# %%
df['Sport'].value_counts()
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10827
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# ### **DISTRIBUTION OF AGE**

# %% [markdown]
# ### **HISTOGRAM**

# %%
sns.histplot(df['Age'],bins=20,kde=True)
plt.show()

# %% [markdown]
# ### **BOXPLOT**

# %%
sns.boxplot(x=df['Age'])
plt.show()

# %%
df['Age'].min()
# Out:
# 10.0

# %%
df['Age'].max()
# Out:
# 97.0

# %%
round(df['Age'].mean(),2)
# Out:
# 25.46

# %%
df['Age'].skew()
# Out:
# 1.5877141959478527

# %% [markdown]
# ### *BIVARIATE ANALYSIS AND MULTIVARIATE ANALYSIS*

# %% [markdown]
# ### **SCATTERPLOT**

# %%
sns.scatterplot(x='Age', y = 'Height',data= df, hue= 'Sex')
plt.show()

# %%
sns.barplot(x='Medal', y='Age', data= df)
plt.show()

# %%
sns.boxplot(x='Medal', y='Age', data= df, hue='Sex')
plt.show()

# %% [markdown]
# ### **HOW MANY GOLD  SILVER AND BRONZE MEDALS HAVE BEEN AWARDED TO MALE AND FEMALE ATHLETES**

# %%
con= pd.crosstab(df['Sex'],df['Medal'])
con
# Out:
# Medal  Bronze  Gold  Silver
# Sex
# F        3771  3747    3735
# M        9524  9622    9373

# %%
sns.heatmap(pd.crosstab(df['Sex'],df['Medal']))
plt.show()

# %% [markdown]
# ### **INDIA OLYMPIC MEDAL WIN**

# %%
df_india = df[df['Team'] =='India']

# %%
india_medal =df_india.groupby('Year')['Medal'].count()

# %%
india_medal
# Out:
# Year
# 1900     2
# 1920     0
# 1924     7
# 1928    14
# 1932    15
# 1936    19
# 1948    20
# 1952    15
# 1956    17
# 1960    13
# 1964    15
# 1968    16
# 1972    14
# 1976     0
# 1980    16
# 1984     0
# 1988     0
# 1992     0
# 1996     1
# 1998     0
# 2000     1
# 2002     0
# 2004     1
# 2006     0
# 2008     3
# 2010     0
# 2012     6
# 2014     0
# 2016     2
# Name: Medal, dtype: int64

# %% [markdown]
# ### **LINEPLOT**

# %%
sns.lineplot(x=india_medal.index, y = india_medal.values)
plt.title("INDIA MEDAL WIN ")
plt.xlabel("YEAR")
plt.ylabel("MEDAL COUNT")
plt.show()

# %%
medal_counts = df['Name'].value_counts().reset_index()

# %%
medal_counts.columns = ['Athlete', 'Medal_count']

# %%
Higher =medal_counts.head(10)

# %%
Higher
# Out:
#                      Athlete  Medal_count
# 0   Heikki Ilmari Savolainen           39
# 1      Joseph "Josy" Stoffel           38
# 2        Ioannis Theofilakis           36
# 3                Takashi Ono           33
# 4     Alexandros Theofilakis           32
# 5             Andreas Wecker           32
# 6  Alfred August "Al" Jochim           31
# 7       Johann "Hans" Sauter           31
# 8             Michel Mathiot           31
# 9    Michael Fred Phelps, II           30

# %%
sns.barplot(x='Medal_count', y='Athlete', data=Higher)
plt.title("Top 10 Winner Medal")
plt.show()
